# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.axes import Axes
from glio2.python_tools.f2f import method2method
from glio2.torch_tools.conversion import ensure_numpy_or_none, maybe_ensure_detach_cpu, ensure_numpy
from glio2.transforms.format import force_hw3
from glio2.plt_tools.fig import Fig

# %%
f = Fig()
f.add().linechart([1,2,3, 2], label = 'x')

f.show()
f.figure.legend()

# %%
x = {"a": 4}
x.setdefault("a", 5)
x.setdefault("b", 5)
x
# Out:
# {'a': 4, 'b': 5}
